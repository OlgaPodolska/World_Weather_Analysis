# %%
# Add the Pandas dependency.
import pandas as pd

# Import Matplotlib
import matplotlib.pyplot as plt

# Import the NumPy module
import numpy as np

# Import CityPy
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Perform an API call with the OpenWeatherMap

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0883204649e3db8f0515471245140af2

# %%
# Retrieve the following information from the API call

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})
                         
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mahebourg
# Processing Record 2 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 1 | tevriz
# Processing Record 4 of Set 1 | norman wells
# Processing Record 5 of Set 1 | kaitangata
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 1 | provideniya
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | raudeberg
# Processing Record 15 of Set 1 | sumbawa
# City not found. Skipping...
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | mata
# Processing Record 21 of Set 1 | sharjah
# Processing Record 22 of Set 1 | jabiru
# City not found. Skipping...
# Processing Record 23 of Set 1 | cherskiy
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | sumbe
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | itarema
# Processing Record 28 of Set 1 | bilma
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | iacu
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | nanortalik
# Processing Record 34 of Set 1 | porto novo
# Processing Record 35 of Set 1 | teluk intan
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | berdigestyakh
# Processing Record 38 of Set 1 | cusco
# Processing Record 39 of Set 1 | nara
# Processing Record 40 of Set 1 | lianzhou
# Processing Record 41 of Set 1 | iqaluit
# Processing Record 42 of Set 1 | torbay
# Processing Record 43 of Set 1 | saint-philippe
# Processing Record 44 of Set 1 | seoul
# Processing Record 45 of Set 1 | eyl
# Processing Record 46 of Set 1 | isangel
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | tattayyangarpettai
# Processing Record 49 of Set 1 | rocha
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | east london
# Processing Record 2 of Set 2 | maceio
# Processing Record 3 of Set 2 | sitka
# Processing Record 4 of Set 2 | sovetskiy
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | pervomayskiy
# Processing Record 8 of Set 2 | krasnoselkup
# Processing Record 9 of Set 2 | faya
# Processing Record 10 of Set 2 | saskylakh
# Processing Record 11 of Set 2 | ostrovnoy
# Processing Record 12 of Set 2 | goderich
# Processing Record 13 of Set 2 | jizan
# Processing Record 14 of Set 2 | ottersberg
# Processing Record 15 of Set 2 | muravlenko
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | miles city
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | whitehorse
# Processing Record 20 of Set 2 | leningradskiy
# Processing Record 21 of Set 2 | ilhabela
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | carnarvon
# Processing Record 24 of Set 2 | bonavista
# Processing Record 25 of Set 2 | diu
# Processing Record 26 of Set 2 | semnan
# Processing Record 27 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 2 | san quintin
# Processing Record 29 of Set 2 | casablanca
# Processing Record 30 of Set 2 | muros
# Processing Record 31 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 2 | keflavik
# Processing Record 33 of Set 2 | severnyy-kospashskiy
# Processing Record 34 of Set 2 | avarua
# Processing Record 35 of Set 2 | xuddur
# Processing Record 36 of Set 2 | kamen-rybolov
# Processing Record 37 of Set 2 | bacolod
# Processing Record 38 of Set 2 | mar del plata
# Processing Record 39 of Set 2 | denpasar
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | kandrian
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | bluff
# Processing Record 44 of Set 2 | kamakwie
# Processing Record 45 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 46 of Set 2 | erenhot
# Processing Record 47 of Set 2 | ambovombe
# Processing Record 48 of Set 2 | ponta do sol
# Processing Record 49 of Set 2 | san patricio
# Processing Record 50 of Set 2 | carballo
# Processing Record 1 of Set 3 | kavieng
# Processing Record 2 of Set 3 | port hardy
# Processing Record 3 of Set 3 | tuktoyaktuk
# Processing Record 4 of Set 3 | ketchikan
# Processing Record 5 of Set 3 | abha
# Processing Record 6 of Set 3 | chokurdakh
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | mopipi
# Processing Record 9 of Set 3 | mezen
# Processing Record 10 of Set 3 | waipawa
# Processing Record 11 of Set 3 | bedele
# Processing Record 12 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 3 | sabla
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | bethel
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | chapais
# Processing Record 18 of Set 3 | mucuri
# Processing Record 19 of Set 3 | amapa
# Processing Record 20 of Set 3 | salalah
# Processing Record 21 of Set 3 | jiazi
# Processing Record 22 of Set 3 | geraldton
# Processing Record 23 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 3 | galle
# Processing Record 25 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 3 | henties bay
# Processing Record 27 of Set 3 | tiksi
# Processing Record 28 of Set 3 | mount gambier
# Processing Record 29 of Set 3 | sosua
# Processing Record 30 of Set 3 | dakar
# Processing Record 31 of Set 3 | ofaqim
# Processing Record 32 of Set 3 | palmer
# Processing Record 33 of Set 3 | matagami
# Processing Record 34 of Set 3 | erzin
# Processing Record 35 of Set 3 | gardner
# Processing Record 36 of Set 3 | caravelas
# Processing Record 37 of Set 3 | meadow lake
# Processing Record 38 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 3 | ola
# Processing Record 40 of Set 3 | sawakin
# Processing Record 41 of Set 3 | mandali
# Processing Record 42 of Set 3 | albania
# Processing Record 43 of Set 3 | yanam
# Processing Record 44 of Set 3 | lorengau
# Processing Record 45 of Set 3 | leland
# Processing Record 46 of Set 3 | chuy
# Processing Record 47 of Set 3 | gazanjyk
# Processing Record 48 of Set 3 | hauterive
# Processing Record 49 of Set 3 | hofn
# Processing Record 50 of Set 3 | darnah
# Processing Record 1 of Set 4 | airai
# Processing Record 2 of Set 4 | yingcheng
# Processing Record 3 of Set 4 | galeana
# Processing Record 4 of Set 4 | ambilobe
# Processing Record 5 of Set 4 | jatiroto
# Processing Record 6 of Set 4 | husavik
# Processing Record 7 of Set 4 | jamestown
# Processing Record 8 of Set 4 | rio gallegos
# Processing Record 9 of Set 4 | lagoa
# Processing Record 10 of Set 4 | gidam
# Processing Record 11 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 12 of Set 4 | tahta
# Processing Record 13 of Set 4 | luangwa
# Processing Record 14 of Set 4 | rajanpur
# Processing Record 15 of Set 4 | ornskoldsvik
# Processing Record 16 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 4 | thinadhoo
# Processing Record 18 of Set 4 | berlevag
# Processing Record 19 of Set 4 | hasaki
# Processing Record 20 of Set 4 | bukama
# Processing Record 21 of Set 4 | grindavik
# Processing Record 22 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 4 | raymondville
# Processing Record 24 of Set 4 | labuhan
# Processing Record 25 of Set 4 | namibe
# Processing Record 26 of Set 4 | tabuk
# Processing Record 27 of Set 4 | aquiraz
# Processing Record 28 of Set 4 | ilulissat
# Processing Record 29 of Set 4 | san carlos
# Processing Record 30 of Set 4 | bathsheba
# Processing Record 31 of Set 4 | puerto ayora
# Processing Record 32 of Set 4 | sisimiut
# Processing Record 33 of Set 4 | lodja
# Processing Record 34 of Set 4 | ahumada
# City not found. Skipping...
# Processing Record 35 of Set 4 | beringovskiy
# Processing Record 36 of Set 4 | burica
# City not found. Skipping...
# Processing Record 37 of Set 4 | sogdiondon
# City not found. Skipping...
# Processing Record 38 of Set 4 | cidreira
# Processing Record 39 of Set 4 | saint george
# Processing Record 40 of Set 4 | amiens
# Processing Record 41 of Set 4 | bengkulu
# Processing Record 42 of Set 4 | yerbogachen
# Processing Record 43 of Set 4 | creel
# Processing Record 44 of Set 4 | itaituba
# Processing Record 45 of Set 4 | sao filipe
# Processing Record 46 of Set 4 | valparaiso
# Processing Record 47 of Set 4 | yenagoa
# Processing Record 48 of Set 4 | luderitz
# Processing Record 49 of Set 4 | georgetown
# Processing Record 50 of Set 4 | launceston
# Processing Record 1 of Set 5 | krasnyy chikoy
# Processing Record 2 of Set 5 | fairbanks
# Processing Record 3 of Set 5 | san vicente
# Processing Record 4 of Set 5 | qaanaaq
# Processing Record 5 of Set 5 | innisfail
# Processing Record 6 of Set 5 | yazd
# Processing Record 7 of Set 5 | sompeta
# Processing Record 8 of Set 5 | olafsvik
# Processing Record 9 of Set 5 | abu samrah
# Processing Record 10 of Set 5 | ngozi
# Processing Record 11 of Set 5 | sur
# Processing Record 12 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 5 | oxford
# Processing Record 14 of Set 5 | lao cai
# Processing Record 15 of Set 5 | xinpu
# Processing Record 16 of Set 5 | panguipulli
# Processing Record 17 of Set 5 | biak
# Processing Record 18 of Set 5 | bredasdorp
# Processing Record 19 of Set 5 | saint-joseph
# Processing Record 20 of Set 5 | touros
# Processing Record 21 of Set 5 | vila franca do campo
# Processing Record 22 of Set 5 | tasiilaq
# Processing Record 23 of Set 5 | palm coast
# Processing Record 24 of Set 5 | puerto escondido
# Processing Record 25 of Set 5 | shu
# Processing Record 26 of Set 5 | shirdi
# Processing Record 27 of Set 5 | kalmunai
# Processing Record 28 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 5 | cradock
# Processing Record 30 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 5 | tautira
# Processing Record 32 of Set 5 | grand-santi
# Processing Record 33 of Set 5 | brae
# Processing Record 34 of Set 5 | pangnirtung
# Processing Record 35 of Set 5 | oranjestad
# Processing Record 36 of Set 5 | balsas
# Processing Record 37 of Set 5 | hirara
# Processing Record 38 of Set 5 | ostersund
# Processing Record 39 of Set 5 | floro
# Processing Record 40 of Set 5 | cayenne
# Processing Record 41 of Set 5 | rio grande
# Processing Record 42 of Set 5 | camabatela
# Processing Record 43 of Set 5 | pacifica
# Processing Record 44 of Set 5 | inverness
# Processing Record 45 of Set 5 | grande-riviere
# City not found. Skipping...
# Processing Record 46 of Set 5 | uhlove
# Processing Record 47 of Set 5 | codrington
# Processing Record 48 of Set 5 | khatanga
# Processing Record 49 of Set 5 | sorland
# Processing Record 50 of Set 5 | sinnamary
# Processing Record 1 of Set 6 | panaba
# Processing Record 2 of Set 6 | necochea
# Processing Record 3 of Set 6 | muhos
# Processing Record 4 of Set 6 | kirakira
# Processing Record 5 of Set 6 | harper
# Processing Record 6 of Set 6 | victoria
# Processing Record 7 of Set 6 | pisco
# Processing Record 8 of Set 6 | vilyuysk
# Processing Record 9 of Set 6 | arona
# Processing Record 10 of Set 6 | kodiak
# Processing Record 11 of Set 6 | myitkyina
# Processing Record 12 of Set 6 | punto fijo
# Processing Record 13 of Set 6 | marienburg
# Processing Record 14 of Set 6 | vastervik
# City not found. Skipping...
# Processing Record 15 of Set 6 | kerman
# Processing Record 16 of Set 6 | lyuban
# Processing Record 17 of Set 6 | kirkwall
# Processing Record 18 of Set 6 | taltal
# Processing Record 19 of Set 6 | mercedes
# Processing Record 20 of Set 6 | samarai
# Processing Record 21 of Set 6 | benoy
# Processing Record 22 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 6 | chunskiy
# Processing Record 24 of Set 6 | manggar
# Processing Record 25 of Set 6 | pathein
# Processing Record 26 of Set 6 | praya
# Processing Record 27 of Set 6 | kaeo
# Processing Record 28 of Set 6 | ouallam
# Processing Record 29 of Set 6 | yantal
# Processing Record 30 of Set 6 | quang ngai
# Processing Record 31 of Set 6 | newark
# Processing Record 32 of Set 6 | mount isa
# Processing Record 33 of Set 6 | calderitas
# Processing Record 34 of Set 6 | vao
# Processing Record 35 of Set 6 | port lincoln
# Processing Record 36 of Set 6 | concordia
# Processing Record 37 of Set 6 | de-kastri
# Processing Record 38 of Set 6 | coyah
# Processing Record 39 of Set 6 | grand-lahou
# Processing Record 40 of Set 6 | marquette
# Processing Record 41 of Set 6 | sampit
# Processing Record 42 of Set 6 | murud
# Processing Record 43 of Set 6 | saint-francois
# Processing Record 44 of Set 6 | aldan
# Processing Record 45 of Set 6 | saldanha
# Processing Record 46 of Set 6 | artyom
# Processing Record 47 of Set 6 | bafang
# Processing Record 48 of Set 6 | ponta delgada
# Processing Record 49 of Set 6 | inhambane
# Processing Record 50 of Set 6 | pilot butte
# Processing Record 1 of Set 7 | vila velha
# Processing Record 2 of Set 7 | saint-augustin
# Processing Record 3 of Set 7 | upernavik
# Processing Record 4 of Set 7 | alofi
# Processing Record 5 of Set 7 | dingle
# Processing Record 6 of Set 7 | klaeng
# Processing Record 7 of Set 7 | klaksvik
# Processing Record 8 of Set 7 | rafai
# Processing Record 9 of Set 7 | kirovskiy
# Processing Record 10 of Set 7 | campbell river
# Processing Record 11 of Set 7 | waingapu
# Processing Record 12 of Set 7 | novikovo
# Processing Record 13 of Set 7 | hovd
# Processing Record 14 of Set 7 | katobu
# Processing Record 15 of Set 7 | lakselv
# Processing Record 16 of Set 7 | kavaratti
# Processing Record 17 of Set 7 | cabo san lucas
# Processing Record 18 of Set 7 | vigrestad
# Processing Record 19 of Set 7 | beloha
# Processing Record 20 of Set 7 | axim
# Processing Record 21 of Set 7 | minnedosa
# Processing Record 22 of Set 7 | girau do ponciano
# Processing Record 23 of Set 7 | east foothills
# Processing Record 24 of Set 7 | iquitos
# Processing Record 25 of Set 7 | flinders
# Processing Record 26 of Set 7 | paoua
# Processing Record 27 of Set 7 | hue
# Processing Record 28 of Set 7 | komsomolskiy
# Processing Record 29 of Set 7 | vung tau
# Processing Record 30 of Set 7 | peniche
# Processing Record 31 of Set 7 | sibolga
# Processing Record 32 of Set 7 | kosh-agach
# Processing Record 33 of Set 7 | kalemie
# Processing Record 34 of Set 7 | gigmoto
# Processing Record 35 of Set 7 | poum
# Processing Record 36 of Set 7 | luanda
# Processing Record 37 of Set 7 | enshi
# Processing Record 38 of Set 7 | ust-kan
# Processing Record 39 of Set 7 | mocuba
# Processing Record 40 of Set 7 | maryville
# Processing Record 41 of Set 7 | talnakh
# Processing Record 42 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 7 | goias
# Processing Record 44 of Set 7 | mehamn
# Processing Record 45 of Set 7 | kindu
# Processing Record 46 of Set 7 | rumphi
# Processing Record 47 of Set 7 | kashan
# Processing Record 48 of Set 7 | coihaique
# Processing Record 49 of Set 7 | kushima
# Processing Record 50 of Set 7 | bagan
# Processing Record 1 of Set 8 | yumen
# Processing Record 2 of Set 8 | tigil
# Processing Record 3 of Set 8 | kongolo
# Processing Record 4 of Set 8 | esperance
# Processing Record 5 of Set 8 | hithadhoo
# Processing Record 6 of Set 8 | linguere
# Processing Record 7 of Set 8 | kirriemuir
# Processing Record 8 of Set 8 | svetlaya
# Processing Record 9 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 10 of Set 8 | pundaguitan
# Processing Record 11 of Set 8 | shakhtinsk
# Processing Record 12 of Set 8 | yulara
# Processing Record 13 of Set 8 | kedougou
# Processing Record 14 of Set 8 | khorinsk
# Processing Record 15 of Set 8 | poltava
# Processing Record 16 of Set 8 | lons
# Processing Record 17 of Set 8 | vostok
# Processing Record 18 of Set 8 | makakilo city
# Processing Record 19 of Set 8 | mapiripan
# Processing Record 20 of Set 8 | goldsboro
# Processing Record 21 of Set 8 | mayumba
# Processing Record 22 of Set 8 | xunchang
# Processing Record 23 of Set 8 | costa rica
# Processing Record 24 of Set 8 | urdoma
# Processing Record 25 of Set 8 | requena
# Processing Record 26 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 8 | souillac
# Processing Record 28 of Set 8 | marathon
# Processing Record 29 of Set 8 | tukrah
# Processing Record 30 of Set 8 | bowen
# Processing Record 31 of Set 8 | guerrero negro
# Processing Record 32 of Set 8 | coetupo
# City not found. Skipping...
# Processing Record 33 of Set 8 | prachuap khiri khan
# Processing Record 34 of Set 8 | san cristobal
# Processing Record 35 of Set 8 | mandalgovi
# Processing Record 36 of Set 8 | benghazi
# Processing Record 37 of Set 8 | nalut
# Processing Record 38 of Set 8 | oranjemund
# Processing Record 39 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 40 of Set 8 | changying
# Processing Record 41 of Set 8 | abtenau
# Processing Record 42 of Set 8 | vardo
# Processing Record 43 of Set 8 | yatou
# Processing Record 44 of Set 8 | petrivka
# Processing Record 45 of Set 8 | bera
# Processing Record 46 of Set 8 | bubaque
# Processing Record 47 of Set 8 | margate
# Processing Record 48 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 8 | paramonga
# Processing Record 50 of Set 8 | verkhnyaya inta
# Processing Record 1 of Set 9 | bonthe
# Processing Record 2 of Set 9 | longhua
# Processing Record 3 of Set 9 | xiazhen
# Processing Record 4 of Set 9 | ridgetown
# Processing Record 5 of Set 9 | spearfish
# Processing Record 6 of Set 9 | acapulco
# Processing Record 7 of Set 9 | fortuna
# Processing Record 8 of Set 9 | lota
# Processing Record 9 of Set 9 | jeremie
# Processing Record 10 of Set 9 | kudahuvadhoo
# Processing Record 11 of Set 9 | khani
# Processing Record 12 of Set 9 | asau
# Processing Record 13 of Set 9 | stilfontein
# Processing Record 14 of Set 9 | mingguang
# Processing Record 15 of Set 9 | samut prakan
# Processing Record 16 of Set 9 | ancud
# Processing Record 17 of Set 9 | jumla
# Processing Record 18 of Set 9 | boende
# Processing Record 19 of Set 9 | jacareacanga
# Processing Record 20 of Set 9 | ust-nera
# Processing Record 21 of Set 9 | taoudenni
# Processing Record 22 of Set 9 | bela
# Processing Record 23 of Set 9 | adrar
# Processing Record 24 of Set 9 | burnie
# Processing Record 25 of Set 9 | nago
# Processing Record 26 of Set 9 | kyzyl-suu
# Processing Record 27 of Set 9 | atbasar
# Processing Record 28 of Set 9 | qianan
# Processing Record 29 of Set 9 | dalbeattie
# Processing Record 30 of Set 9 | karratha
# Processing Record 31 of Set 9 | oktyabrskiy
# Processing Record 32 of Set 9 | skibotn
# Processing Record 33 of Set 9 | clyde river
# Processing Record 34 of Set 9 | pangkalanbuun
# Processing Record 35 of Set 9 | jiroft
# City not found. Skipping...
# Processing Record 36 of Set 9 | yarada
# Processing Record 37 of Set 9 | veraval
# Processing Record 38 of Set 9 | fochville
# Processing Record 39 of Set 9 | bartica
# Processing Record 40 of Set 9 | hailun
# Processing Record 41 of Set 9 | canico
# Processing Record 42 of Set 9 | faanui
# Processing Record 43 of Set 9 | rawson
# Processing Record 44 of Set 9 | manado
# Processing Record 45 of Set 9 | aripuana
# Processing Record 46 of Set 9 | svencionys
# Processing Record 47 of Set 9 | maumere
# Processing Record 48 of Set 9 | longyearbyen
# Processing Record 49 of Set 9 | gao
# Processing Record 50 of Set 9 | isilkul
# Processing Record 1 of Set 10 | yeppoon
# Processing Record 2 of Set 10 | kuragino
# Processing Record 3 of Set 10 | avera
# Processing Record 4 of Set 10 | igrim
# Processing Record 5 of Set 10 | langub
# Processing Record 6 of Set 10 | lata
# Processing Record 7 of Set 10 | haines junction
# Processing Record 8 of Set 10 | pevek
# Processing Record 9 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 10 of Set 10 | ambatondrazaka
# Processing Record 11 of Set 10 | zhuzhou
# Processing Record 12 of Set 10 | sola
# Processing Record 13 of Set 10 | taitung
# Processing Record 14 of Set 10 | reefton
# City not found. Skipping...
# Processing Record 15 of Set 10 | cochrane
# Processing Record 16 of Set 10 | saeby
# Processing Record 17 of Set 10 | villanueva
# Processing Record 18 of Set 10 | aklavik
# Processing Record 19 of Set 10 | lompoc
# Processing Record 20 of Set 10 | severo-kurilsk
# Processing Record 21 of Set 10 | bilibino
# Processing Record 22 of Set 10 | saint anthony
# Processing Record 23 of Set 10 | langsa
# Processing Record 24 of Set 10 | mushie
# Processing Record 25 of Set 10 | walvis bay
# Processing Record 26 of Set 10 | comodoro rivadavia
# Processing Record 27 of Set 10 | nemuro
# Processing Record 28 of Set 10 | christchurch
# Processing Record 29 of Set 10 | itoman
# Processing Record 30 of Set 10 | lavrentiya
# Processing Record 31 of Set 10 | batemans bay
# Processing Record 32 of Set 10 | huron
# Processing Record 33 of Set 10 | dembi dolo
# Processing Record 34 of Set 10 | qaqortoq
# Processing Record 35 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 10 | macau
# Processing Record 37 of Set 10 | mitsamiouli
# Processing Record 38 of Set 10 | larsnes
# Processing Record 39 of Set 10 | natal
# Processing Record 40 of Set 10 | lillooet
# Processing Record 41 of Set 10 | dutlwe
# Processing Record 42 of Set 10 | jaguarari
# Processing Record 43 of Set 10 | myszkow
# Processing Record 44 of Set 10 | amboasary
# Processing Record 45 of Set 10 | xai-xai
# Processing Record 46 of Set 10 | sal rei
# Processing Record 47 of Set 10 | sulangan
# Processing Record 48 of Set 10 | vallenar
# Processing Record 49 of Set 10 | kajaani
# Processing Record 50 of Set 10 | falaleu
# City not found. Skipping...
# Processing Record 1 of Set 11 | sorong
# Processing Record 2 of Set 11 | bathurst
# Processing Record 3 of Set 11 | changli
# Processing Record 4 of Set 11 | bontang
# Processing Record 5 of Set 11 | gweta
# Processing Record 6 of Set 11 | raipur
# Processing Record 7 of Set 11 | sakakah
# Processing Record 8 of Set 11 | riyadh
# Processing Record 9 of Set 11 | ust-ilimsk
# Processing Record 10 of Set 11 | chishtian mandi
# Processing Record 11 of Set 11 | japura
# Processing Record 12 of Set 11 | portland
# Processing Record 13 of Set 11 | baoshan
# Processing Record 14 of Set 11 | lephepe
# City not found. Skipping...
# Processing Record 15 of Set 11 | saint-pierre
# Processing Record 16 of Set 11 | moose factory
# Processing Record 17 of Set 11 | coahuayana
# Processing Record 18 of Set 11 | zhaocheng
# City not found. Skipping...
# Processing Record 19 of Set 11 | kalabo
# Processing Record 20 of Set 11 | abeche
# Processing Record 21 of Set 11 | den helder
# Processing Record 22 of Set 11 | sioux lookout
# Processing Record 23 of Set 11 | xucheng
# Processing Record 24 of Set 11 | sao jose da coroa grande
# Processing Record 25 of Set 11 | dunedin
# Processing Record 26 of Set 11 | lazaro cardenas
# Processing Record 27 of Set 11 | spirit river
# Processing Record 28 of Set 11 | invermere
# Processing Record 29 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 30 of Set 11 | san matias
# Processing Record 31 of Set 11 | meulaboh
# Processing Record 32 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 33 of Set 11 | tokmak
# Processing Record 34 of Set 11 | bahia honda
# Processing Record 35 of Set 11 | alekseyevskaya
# Processing Record 36 of Set 11 | paamiut
# Processing Record 37 of Set 11 | la tuque
# Processing Record 38 of Set 11 | howard springs
# Processing Record 39 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 11 | eureka
# Processing Record 41 of Set 11 | ambon
# Processing Record 42 of Set 11 | barrhead
# Processing Record 43 of Set 11 | berezniki
# Processing Record 44 of Set 11 | hualmay
# Processing Record 45 of Set 11 | katsuura
# Processing Record 46 of Set 11 | swidwin
# Processing Record 47 of Set 11 | bambous virieux
# Processing Record 48 of Set 11 | effingham
# Processing Record 49 of Set 11 | fort nelson
# Processing Record 50 of Set 11 | wolmaranstad
# City not found. Skipping...
# Processing Record 1 of Set 12 | bubanza
# Processing Record 2 of Set 12 | namatanai
# Processing Record 3 of Set 12 | juegang
# Processing Record 4 of Set 12 | west bay
# Processing Record 5 of Set 12 | anloga
# Processing Record 6 of Set 12 | mira
# Processing Record 7 of Set 12 | radcliff
# Processing Record 8 of Set 12 | stepnogorsk
# Processing Record 9 of Set 12 | doha
# Processing Record 10 of Set 12 | tuscaloosa
# Processing Record 11 of Set 12 | sillamae
# Processing Record 12 of Set 12 | tanout
# Processing Record 13 of Set 12 | havelock
# Processing Record 14 of Set 12 | hays
# Processing Record 15 of Set 12 | ternate
# Processing Record 16 of Set 12 | kysyl-syr
# Processing Record 17 of Set 12 | elat
# Processing Record 18 of Set 12 | alamosa
# Processing Record 19 of Set 12 | naryan-mar
# Processing Record 20 of Set 12 | vagur
# Processing Record 21 of Set 12 | hokitika
# Processing Record 22 of Set 12 | velyka mykhaylivka
# Processing Record 23 of Set 12 | kisangani
# Processing Record 24 of Set 12 | belmonte
# Processing Record 25 of Set 12 | xiuyan
# Processing Record 26 of Set 12 | kruisfontein
# Processing Record 27 of Set 12 | srivaikuntam
# Processing Record 28 of Set 12 | mayo
# Processing Record 29 of Set 12 | agirish
# Processing Record 30 of Set 12 | vestmannaeyjar
# Processing Record 31 of Set 12 | atka
# City not found. Skipping...
# Processing Record 32 of Set 12 | naze
# Processing Record 33 of Set 12 | belmopan
# Processing Record 34 of Set 12 | arroyos y esteros
# Processing Record 35 of Set 12 | bushehr
# Processing Record 36 of Set 12 | nishihara
# Processing Record 37 of Set 12 | tual
# Processing Record 38 of Set 12 | evensk
# Processing Record 39 of Set 12 | new kensington
# Processing Record 40 of Set 12 | honiara
# Processing Record 41 of Set 12 | sragen
# Processing Record 42 of Set 12 | rancho palos verdes
# Processing Record 43 of Set 12 | victoriaville
# Processing Record 44 of Set 12 | kholtoson
# Processing Record 45 of Set 12 | half moon bay
# Processing Record 46 of Set 12 | manta
# Processing Record 47 of Set 12 | beidao
# Processing Record 48 of Set 12 | vanimo
# Processing Record 49 of Set 12 | jieshi
# Processing Record 50 of Set 12 | madison
# Processing Record 1 of Set 13 | shuyskoye
# Processing Record 2 of Set 13 | belaya gora
# Processing Record 3 of Set 13 | port moresby
# Processing Record 4 of Set 13 | pochutla
# Processing Record 5 of Set 13 | tucumcari
# Processing Record 6 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 13 | poronaysk
# Processing Record 8 of Set 13 | mabaruma
# Processing Record 9 of Set 13 | cabedelo
# Processing Record 10 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 13 | constitucion
# Processing Record 12 of Set 13 | port macquarie
# Processing Record 13 of Set 13 | aksarka
# Processing Record 14 of Set 13 | pandamatenga
# Processing Record 15 of Set 13 | port-gentil
# Processing Record 16 of Set 13 | pitimbu
# Processing Record 17 of Set 13 | kawalu
# Processing Record 18 of Set 13 | jinxiang
# Processing Record 19 of Set 13 | trincomalee
# Processing Record 20 of Set 13 | anadyr
# Processing Record 21 of Set 13 | ozinki
# Processing Record 22 of Set 13 | tazovskiy
# Processing Record 23 of Set 13 | bhattiprolu
# Processing Record 24 of Set 13 | dauriya
# Processing Record 25 of Set 13 | byron bay
# Processing Record 26 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 27 of Set 13 | palana
# Processing Record 28 of Set 13 | ngunguru
# Processing Record 29 of Set 13 | yaring
# Processing Record 30 of Set 13 | ithaca
# Processing Record 31 of Set 13 | honningsvag
# Processing Record 32 of Set 13 | alihe
# Processing Record 33 of Set 13 | swan hill
# Processing Record 34 of Set 13 | mnogovershinnyy
# Processing Record 35 of Set 13 | austin
# Processing Record 36 of Set 13 | pozo colorado
# Processing Record 37 of Set 13 | syamzha
# Processing Record 38 of Set 13 | te anau
# Processing Record 39 of Set 13 | bunia
# Processing Record 40 of Set 13 | temax
# Processing Record 41 of Set 13 | ayr
# Processing Record 42 of Set 13 | la ronge
# Processing Record 43 of Set 13 | negombo
# Processing Record 44 of Set 13 | shushenskoye
# Processing Record 45 of Set 13 | pudozh
# Processing Record 46 of Set 13 | duluth
# Processing Record 47 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 48 of Set 13 | panzhihua
# Processing Record 49 of Set 13 | snasa
# Processing Record 50 of Set 13 | anisoc
# Processing Record 1 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 14 | umm kaddadah
# Processing Record 3 of Set 14 | port hedland
# Processing Record 4 of Set 14 | lysva
# Processing Record 5 of Set 14 | narsaq
# Processing Record 6 of Set 14 | kholmogory
# Processing Record 7 of Set 14 | mitu
# Processing Record 8 of Set 14 | bandar-e anzali
# Processing Record 9 of Set 14 | kenora
# Processing Record 10 of Set 14 | heihe
# Processing Record 11 of Set 14 | santa isabel do rio negro
# Processing Record 12 of Set 14 | khirkiya
# Processing Record 13 of Set 14 | sunrise manor
# Processing Record 14 of Set 14 | channel-port aux basques
# Processing Record 15 of Set 14 | murwillumbah
# Processing Record 16 of Set 14 | umm lajj
# Processing Record 17 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 18 of Set 14 | pyay
# Processing Record 19 of Set 14 | coquimbo
# Processing Record 20 of Set 14 | marawi
# Processing Record 21 of Set 14 | baruun-urt
# Processing Record 22 of Set 14 | sobolevo
# Processing Record 23 of Set 14 | nome
# Processing Record 24 of Set 14 | sibu
# Processing Record 25 of Set 14 | carlyle
# Processing Record 26 of Set 14 | pingdingshan
# Processing Record 27 of Set 14 | vysokogornyy
# Processing Record 28 of Set 14 | breyten
# Processing Record 29 of Set 14 | ninghai
# Processing Record 30 of Set 14 | ndungu
# Processing Record 31 of Set 14 | huai thalaeng
# Processing Record 32 of Set 14 | bandarbeyla
# Processing Record 33 of Set 14 | mahbubnagar
# Processing Record 34 of Set 14 | quatre cocos
# Processing Record 35 of Set 14 | chabahar
# Processing Record 36 of Set 14 | clonakilty
# Processing Record 37 of Set 14 | los llanos de aridane
# Processing Record 38 of Set 14 | cabo rojo
# Processing Record 39 of Set 14 | zapolyarnyy
# Processing Record 40 of Set 14 | sept-iles
# Processing Record 41 of Set 14 | verkhnetulomskiy
# Processing Record 42 of Set 14 | hueyapan
# Processing Record 43 of Set 14 | morondava
# Processing Record 44 of Set 14 | malindi
# Processing Record 45 of Set 14 | garissa
# Processing Record 46 of Set 14 | klyuchi
# Processing Record 47 of Set 14 | monaragala
# Processing Record 48 of Set 14 | banda aceh
# Processing Record 49 of Set 14 | coruripe
# Processing Record 50 of Set 14 | ibipeba
# Processing Record 1 of Set 15 | clarksburg
# Processing Record 2 of Set 15 | luganville
# Processing Record 3 of Set 15 | morant bay
# Processing Record 4 of Set 15 | puerto carreno
# Processing Record 5 of Set 15 | sankt veit
# Processing Record 6 of Set 15 | bima
# Processing Record 7 of Set 15 | anar darreh
# City not found. Skipping...
# Processing Record 8 of Set 15 | santander
# Processing Record 9 of Set 15 | skelleftea
# Processing Record 10 of Set 15 | lakatoro
# Processing Record 11 of Set 15 | lasa
# Processing Record 12 of Set 15 | korla
# Processing Record 13 of Set 15 | bewar
# Processing Record 14 of Set 15 | ambunti
# Processing Record 15 of Set 15 | puerto leguizamo
# Processing Record 16 of Set 15 | chokwe
# Processing Record 17 of Set 15 | tselinnoye
# Processing Record 18 of Set 15 | geresk
# City not found. Skipping...
# Processing Record 19 of Set 15 | bayangol
# Processing Record 20 of Set 15 | tadine
# Processing Record 21 of Set 15 | xining
# Processing Record 22 of Set 15 | lethem
# Processing Record 23 of Set 15 | atar
# Processing Record 24 of Set 15 | nata
# Processing Record 25 of Set 15 | visby
# Processing Record 26 of Set 15 | visnes
# Processing Record 27 of Set 15 | pascagoula
# Processing Record 28 of Set 15 | west islip
# Processing Record 29 of Set 15 | bogo
# Processing Record 30 of Set 15 | gubkinskiy
# Processing Record 31 of Set 15 | ormara
# Processing Record 32 of Set 15 | srednekolymsk
# Processing Record 33 of Set 15 | hami
# Processing Record 34 of Set 15 | mbanza-ngungu
# Processing Record 35 of Set 15 | pekan
# Processing Record 36 of Set 15 | kumasi
# Processing Record 37 of Set 15 | deputatskiy
# Processing Record 38 of Set 15 | santo domingo
# Processing Record 39 of Set 15 | fond du lac
# Processing Record 40 of Set 15 | conakry
# Processing Record 41 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 15 | ixtapa
# Processing Record 43 of Set 15 | las vegas
# Processing Record 44 of Set 15 | davenda
# Processing Record 45 of Set 15 | bababe
# City not found. Skipping...
# Processing Record 46 of Set 15 | siguiri
# Processing Record 47 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 15 | matara
# Processing Record 49 of Set 15 | alappuzha
# Processing Record 50 of Set 15 | schneverdingen
# Processing Record 1 of Set 16 | bandiagara
# Processing Record 2 of Set 16 | flin flon
# Processing Record 3 of Set 16 | nador
# Processing Record 4 of Set 16 | winkler
# Processing Record 5 of Set 16 | sukumo
# Processing Record 6 of Set 16 | sabha
# Processing Record 7 of Set 16 | dwarka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Mahebourg      MU -20.4081   57.7000     73.69        83          40
# 1        Tevriz      RU  57.5090   72.4042     59.11        65          91
# 2  Norman Wells      CA  65.2820 -126.8329     39.24        65         100
# 3    Kaitangata      NZ -46.2817  169.8464     53.08        71          67
# 4      Thompson      CA  55.7435  -97.8558     42.96        93         100
# 5       Mataura      NZ -46.1927  168.8643     51.48        66          29
# 6     Busselton      AU -33.6500  115.3333     61.29        59         100
# 7        Atuona      PF  -9.8000 -139.0333     78.31        79          10
# 8         Kapaa      US  22.0752 -159.3190     82.38        70           0
# 9   Provideniya      RU  64.3833 -173.3000     36.28        92         100
#
#    Wind Speed Current Description
# 0        8.05    scattered clouds
# 1        7.96     overcast clouds
# 2       18.41     overcast clouds
# 3        5.01       broken clouds
# 4        3.44                mist
# 5        2.21    scattered clouds
# 6        8.61     overcast clouds
# 7       17.45          light rain
# 8       14.97           clear sky
# 9        8.97     overcast clouds

# %%
# Export the DataFrame as a CSV file

# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
